# %%
import sys
sys.path.append('../')

from lab import test
from train_agent import train_agent

# %%
train_agent(test.test_gridworld)
# Out:
# /home/andrea/miniconda3/envs/kernel-transfer/lib/python3.6/site-packages/ipykernel_launcher.py --f=/run/user/1000/jupyter/runtime/kernel-v34f1ba7faa681a0d1fcbecc544c9f29ab06522bd1.json
#
# Args(algo='ppo', env='Letter-7x7-v3', ltl_sampler='Eventually_1_5_1_4', model=None, seed=1, log_interval=5, save_interval=20, procs=16, frames=20000000, checkpoint_dir=None, eval=False, eval_episodes=5, eval_env=None, ltl_samplers_eval=None, eval_procs=1, epochs=4, batch_size=256, frames_per_proc=None, discount=0.94, lr=0.0003, gae_lambda=0.95, entropy_coef=0.01, value_loss_coef=0.5, max_grad_norm=0.5, optim_eps=1e-08, optim_alpha=0.99, clip_eps=0.2, ignoreLTL=False, noLTL=False, progression_mode='full', recurrence=1, gnn='RGCN_8x32_ROOT_SHARED', int_reward=0.0, pretrained_gnn=False, dumb_ac=False, freeze_ltl=False)
#
# Device: cpu
#
# Using fixed maps.
# Environments loaded
#
# Training status loaded.
#
# Observations preprocessor loaded.
#
# GNN Number of parameters: 10016
# embedding size: 1024
# ...
